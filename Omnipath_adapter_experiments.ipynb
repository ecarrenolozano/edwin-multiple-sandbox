# %% [markdown]
# # Experiment: using pypath to recreate the datab

# %%
from pypath import omnipath
op = omnipath.db.get_db('omnipath')
# Out:
# [2024-10-14 08:40:28] [network] Traceback (most recent call last):
# [2024-10-14 08:40:28] [network]   File "/tmp/ipykernel_10850/937001079.py", line 2, in <module>
# [2024-10-14 08:40:28] [network]     op = omnipath.db.get_db('omnipath')
# [2024-10-14 08:40:28] [network]   File "/home/ecarreno/miniconda3/envs/pypath_env/lib/python3.12/site-packages/pypath/omnipath/app.py", line 492, in get_db
# [2024-10-14 08:40:28] [network]     self.ensure_dataset(dataset, ncbi_tax_id = ncbi_tax_id)
# [2024-10-14 08:40:28] [network]   File "/home/ecarreno/miniconda3/envs/pypath_env/lib/python3.12/site-packages/pypath/omnipath/app.py", line 136, in ensure_dataset
# [2024-10-14 08:40:28] [network]     self.build_dataset(dataset, ncbi_tax_id = ncbi_tax_id)
# [2024-10-14 08:40:28] [network]   File "/home/ecarreno/miniconda3/envs/pypath_env/lib/python3.12/site-packages/pypath/omnipath/app.py", line 256, in build_dataset
# [2024-10-14 08:40:28] [network]     db = mod.get_db(**args)
# ...
